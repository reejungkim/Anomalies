# %%
import timeit
import datetime as dt
import os
import subprocess 

import pandas as pd
import numpy as np
from scipy.stats import norm


#visualization
import matplotlib.pyplot as plt
#import plotly.graph_objs as go
# %matplotlib inline
#visualization with seaborn
import seaborn as sns
#visualization with plotly 
import plotly.graph_objects as go #for candle chart visualization
import plotly.express as px #for html output


from sklearn.preprocessing import StandardScaler, RobustScaler
std_scaler = StandardScaler()
rob_scaler = RobustScaler()

# %%
os.getcwd()
# Out:
# '/Users/reejungkim/Documents/Git/Anomaly Detection'

# %%
df = pd.read_csv('/Users/reejungkim/Documents/python functions/creditcard 2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %% [markdown]
# df.isnull().sum()

# %%
normal = df.loc[df.Class == 0]
fraud = df.loc[df.Class == 1]

# %%
print("Fraud rate: " )
len(fraud)/(len(fraud)+len(normal))*100
# Out:
# Fraud rate:
# 0.1727485630620034

# %%
display(fraud['Amount'].describe()), display(normal['Amount'].describe())
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64
# (None, None)

# %% [markdown]
# import seaborn as sns
# sns.pairplot(df.loc[df['Class']==1])

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
normal.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %% [markdown]
# fig, ax = plt.subplots(1, 2, figsize=(18,4))
#
# amount_val = df['Amount'].values
# time_val = df['Time'].values
#
# sns.distplot(amount_val, ax=ax[0], color='y')
# sns.distplot(fraud['Amount'].values , ax = ax[0], color ='r', label='fraud')
# sns.distplot(normal['Amount'].values , ax = ax[0], color ='b', label='normal')
# ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
# ax[0].legend()
# ax[0].set_xlim([min(amount_val), max(fraud['Amount'])])
#
# sns.distplot(time_val, ax=ax[1], color='y')
# sns.distplot(fraud['Time'].values, ax=ax[1], color='r', label='fraud')
# sns.distplot(normal['Time'].values, ax=ax[1], color='b', label='normal')
# ax[1].set_title('Distribution of Transaction Time', fontsize=14)
# ax[1].set_xlim([min(time_val), max(time_val)])
# ax[1].legend()
#
# plt.show()

# %%
n = df.columns.nunique()
n
# Out:
# 31

# %%
count=0
fig, ax = plt.subplots(round(n/2), 2, figsize=(8,10))

for i in df.columns.tolist()[:30]:
    sns.distplot(df[i], ax=ax.flatten()[count], color='y')
    sns.distplot(fraud[i].values , ax = ax.flatten()[count], color ='r', label='fraud')
    sns.distplot(normal[i].values , ax = ax.flatten()[count], color ='b', label='normal')
    ax.flatten()[count].set_title('Distribution of '+ i, fontsize=14)
    #ax[counRow, countCol].legend()
    ax.flatten()[count].set_xlim([min(df[i]), max(df[i])])
    count = count+1


plt.show()

# %% [markdown]
# ## scaling data

# %%
df['Time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))
df['Amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1, 1))

# %%
df.corr()['Class']
# Out:
# Time     -0.012323
# V1       -0.101347
# V2        0.091289
# V3       -0.192961
# V4        0.133447
# V5       -0.094974
# V6       -0.043643
# V7       -0.187257
# V8        0.019875
# V9       -0.097733
# V10      -0.216883
# V11       0.154876
# V12      -0.260593
# V13      -0.004570
# V14      -0.302544
# V15      -0.004223
# V16      -0.196539
# V17      -0.326481
# V18      -0.111485
# V19       0.034783
# V20       0.020090
# V21       0.040413
# V22       0.000805
# V23      -0.002685
# V24      -0.007221
# V25       0.003308
# V26       0.004455
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# Class     1.000000
# Name: Class, dtype: float64

# %%
colormap = plt.cm.Greens

plt.figure(figsize=(14,12))

sns.heatmap(df.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap = colormap, linecolor='white', annot=True)
#plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------

# %% [markdown]
# ## application of principal component analysis

# %% [markdown]
# x = df.loc[:, df.columns!='Class']

# %% [markdown]
# from sklearn.decomposition import PCA
# pca = PCA(n_components=5)
# principalComponents = pca.fit_transform(x)

# %% [markdown]
# principalDf = pd.DataFrame(data = principalComponents)
#              #, columns = ['principal component 1', 'principal component 2'])

# %% [markdown]
# finalDf = pd.concat([principalDf, df['Class']], axis=1)
# finalDf

# %% [markdown]
# sns.pairplot(finalDf)

# %% [markdown]
# sns.heatmap(finalDf.corr())

# %% [markdown]
# finalDf.corr()['Class']

# %% [markdown]
# x = finalDf.loc[:, finalDf.columns !='Class'].values

# %% [markdown]
# df = finalDf

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # random forest classifier

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0      -0.994983  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1      -0.994983   1.191857   0.266151  0.166480  0.448154  0.060018
# 2      -0.994972  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3      -0.994972  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4      -0.994960  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  1.034951 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  1.034963  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  1.034975   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  1.034975  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  1.035022  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
from sklearn.model_selection import train_test_split


x = df.loc[:, df.columns!='Class'].values  #df.loc[:, df.columns!='Class'].to_numpy() <-same
y = df.loc[:, df.columns =='Class'].values.ravel()
# This is explicitly used for undersampling.
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size=0.2)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((227845, 30), (56962, 30), (227845,), (56962,))

# %%
# Building the Random Forest Classifier (RANDOM FOREST)
from sklearn.ensemble import RandomForestClassifier
# random forest model creation
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#training score
print("Train score: %0.3f" % rfc.score(x_train, y_train))
print("Test score: %0.3f" % rfc.score(x_test, y_test))
# Out:
# Train score: 1.000
# Test score: 1.000

# %%
# predictions
y_pred = rfc.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
features = df.loc[:, df.columns!='Class'].columns.values
importances = rfc.feature_importances_

# %%
pd.Series(importances, index=features).sort_values(ascending=False).head(5)
# Out:
# V17    0.158027
# V12    0.142604
# V14    0.131668
# V10    0.073345
# V11    0.058969
# dtype: float64

# %%
feat_importances = pd.Series(importances, index=features)
feat_importances.sort_values(ascending=True).plot(kind='bar')
#feat_importances.nlargest(5).sort_values(ascending=True).plot(kind='barh')

# %%
dfFeatures = pd.DataFrame(feat_importances.nlargest(5), columns=['importance'])
dfFeatures
# Out:
#      importance
# V17    0.158027
# V12    0.142604
# V14    0.131668
# V10    0.073345
# V11    0.058969

# %%
count=0
fig, ax = plt.subplots(5, 1, figsize=(15,10))

for i in dfFeatures.index:
    #sns.distplot(df[i], ax=ax.flatten()[count], color='y')
    sns.distplot(fraud[i].values , ax = ax.flatten()[count], color ='r', label='fraud')
    sns.distplot(normal[i].values , ax = ax.flatten()[count], color ='b', label='normal')
    ax.flatten()[count].set_title('Distribution of '+ i, fontsize=14)
    #ax[counRow, countCol].legend()
    ax.flatten()[count].set_xlim([min(df[i]), max(df[i])])
    count = count+1

plt.show()

# %%
from sklearn.linear_model import LogisticRegression

logistics = LogisticRegression()
logistics.fit(x_train, y_train)


print(logistics.score(x_train, y_train)) 
print(logistics.score(x_test, y_test))
# Out:
# 0.9991573218635476
# 0.9991046662687406

# %%
y_pred_logistics = logistics.predict(x_test)
y_pred_logistics
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
